# %% [markdown]
# <a href="https://colab.research.google.com/github/rjmango/Sesouh---UPCSG-Hackathon-2025/blob/main/RJ_copy_BioMedical_Waste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Mar  4 07:54:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 40.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 31.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 171.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 177.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 35.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 70.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 65.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 69.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 133.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %cd /content
# !unzip Med_Dataset.zip -d dataset/
# Out:
# /content
# Archive:  runs.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of runs.zip or
#         runs.zip.zip, and cannot find runs.zip.ZIP, period.

# %%
# !unzip runs.zip -d runs/
# Out:
# Archive:  runs.zip
#    creating: runs/runs/detect/
#    creating: runs/runs/detect/predict/
#   inflating: runs/runs/detect/predict/abc2_jpg.rf.b1a8c364d747c3bd496aa5a99f8eea39.jpg
#   inflating: runs/runs/detect/predict/Ambidextrous-Latex-Disposable-Medical-Gloves-_-Natural_jpg.rf.34bc7e14ef9ff22a6a73301bdebee516.jpg
#   inflating: runs/runs/detect/predict/b-11-_jpg.rf.1de06d4ad4d3d096596ab227367cf5f0.jpg
#   inflating: runs/runs/detect/predict/b-18-_jpg.rf.389c6f18350c8bb778fc3cd126a8f924.jpg
#   inflating: runs/runs/detect/predict/b-39-_jpg.rf.bbea5afb5c1f29fabe5e92a090fcd47d.jpg
#   inflating: runs/runs/detect/predict/b-42-_jpg.rf.c5382f58d348db8c52d16cb1d17d384d.jpg
#   inflating: runs/runs/detect/predict/b-46-_jpg.rf.aaf5613373c21fb801fceb6563cce426.jpg
#   inflating: runs/runs/detect/predict/b-48-_jpg.rf.7ccecc8263c2420e6afd8749a839cf55.jpg
#   inflating: runs/runs/detect/predict/b-49-_jpg.rf.831aca047642ac18f8478c4c6c2a0cf8.jpg
# ...

# %%
# !yolo detect train data=/content/dataset/data.yaml model=best.pt epochs=40 imgsz=640
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train \
  model=/content/runs/detect/train3/weights/best.pt \
  data=/content/dataset/data.yaml \
  epochs=20
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect val model=/content/runs/detect/train4/weights/best.pt data=/content/dataset/data.yaml
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 68,135,124 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/dataset/valid/labels.cache... 209 images, 9 backgrounds, 0 corrupt: 100% 209/209 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 9, len(boxes) = 561. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 14/14 [00:14<00:00,  1.05s/it]
#                    all        209        561      0.765      0.662      0.717      0.537
#                 IVtube         23         26      0.799      0.615      0.716      0.508
#                bandage         31        112      0.906      0.856      0.938      0.833
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train4/weights/best.pt source=/content/dataset/valid/images save=True
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 68,135,124 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/209 /content/dataset/valid/images/10_jpg.rf.8c98ea658baba3bbcf4370b694a856c8.jpg: 640x640 1 scissors, 88.0ms
# image 2/209 /content/dataset/valid/images/12_png.rf.f52088fdccb42a2ae447f4923ccb71e7.jpg: 640x640 1 scissors, 54.0ms
# image 3/209 /content/dataset/valid/images/18_jpg.rf.0523f74f98b4c12f48ed44b69e601bd4.jpg: 640x640 1 scissors, 58.8ms
# image 4/209 /content/dataset/valid/images/2021-09-29-11_41_01-Window-260x320_png.rf.9b5d0b5bcfd2e0460e803c3717c86d54.jpg: 640x640 3 vials, 56.7ms
# image 5/209 /content/dataset/valid/images/20_png.rf.f436539c3c623bffed319428efb4feff.jpg: 640x640 1 IVtube, 1 scissors, 56.3ms
# image 6/209 /content/dataset/valid/images/21_png.rf.41a820540e277e58484bdc9d3ec24765.jpg: 640x640 2 bandages, 58.2ms
# ...

# %%
# !zip -r /content/results.zip /content/runs/detect
# Out:
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/product_image_jp_surgical_gloves_jpg.rf.8ee712bd9044c9a458eac53d16ab7803.jpg (deflated 4%)
#   adding: content/runs/detect/predict/vial-73-_jpg.rf.4ab67009d503f663a6739a31190ae954.jpg (deflated 24%)
#   adding: content/runs/detect/predict/BANDAGE-169-_jpg.rf.066dc24bbbf2b533a2433d6ad8156f06.jpg (deflated 11%)
#   adding: content/runs/detect/predict/Cotton-114-_jpg.rf.cb0b281a71f4517f18d46738e1fdc2a3.jpg (deflated 9%)
#   adding: content/runs/detect/predict/RT-34-_jpg.rf.390f35e4e3d43365a7bd52c8bbf9e70c.jpg (deflated 4%)
#   adding: content/runs/detect/predict/b-49-_jpg.rf.1b0e356894c900c562647c5e8fea7635.jpg (deflated 7%)
#   adding: content/runs/detect/predict/b-11-_jpg.rf.66f0e5f36a454e1c6803e6c6e8a1e745.jpg (deflated 9%)
#   adding: content/runs/detect/predict/vial-87-_jpg.rf.c5411fd871efa230815957416318bdae.jpg (deflated 8%)
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path))

# %%
from google.colab import files
files.download("/content/results.zip")
